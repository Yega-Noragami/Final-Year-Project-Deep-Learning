# %%
import os
import shutil
import csv
import sys
import pandas as pd
current = os.getcwd()

# %%
data=pd.read_excel('move-pictures.xlsx',header=None)
data
# Out:
#                                        0        1
# 0    health/20201116-120743__DSC0032.jpg   Health
# 1    health/20201116-120903__DSC0041.jpg  Grade-2
# 2    health/20201116-120903__DSC0042.jpg  Grade-2
# 3    health/20201116-120911__DSC0045.jpg  Grade-2
# 4    health/20201116-120911__DSC0046.jpg  Grade-2
# ..                                   ...      ...
# 232   two/20201116-143510__DSC0082_2.jpg  Grade-2
# 233   two/20201116-143541__DSC0096_2.jpg  Grade-1
# 234     two/20201116-143807__DSC0114.jpg  Grade-1
# 235     two/20201116-143807__DSC0115.jpg  Grade-1
# 236     two/20201116-143922__DSC0124.jpg  Grade-2
#
# [237 rows x 2 columns]

# %%
source = data[0].tolist()
destination = data[1].tolist()
for i in range(len(destination)):
    destination[i] = 'copy/'+destination[i]
    print(destination[i])
# Out:
# copy/Health
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Health
# copy/Grade-1-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-1
# copy/Grade-1-2
# copy/Grade-2
# copy/Grade-1-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-1
# copy/Grade-1-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Health
# copy/Grade-2
# copy/Grade-1-2
# copy/Grade-1-2
# copy/Grade-2
# copy/Health-Unused
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Health
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-1-2
# copy/Grade-1-2
# copy/Grade-1-2
# copy/Grade-2
# copy/Grade-2
# copy/Health-Unused
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2
# copy/Grade-2-Health
# copy/Grade-2
# ...

# %%
for i in range (len(data)):
    s=source[i]
    d=destination[i]
    shutil.move(s,d)
    print(s,'-> ',d)
# Out:
# health/20201116-120743__DSC0032.jpg ->  copy/Health
# health/20201116-120903__DSC0041.jpg ->  copy/Grade-2
# health/20201116-120903__DSC0042.jpg ->  copy/Grade-2
# health/20201116-120911__DSC0045.jpg ->  copy/Grade-2
# health/20201116-120911__DSC0046.jpg ->  copy/Grade-2
# health/20201116-120936__DSC0066.jpg ->  copy/Grade-2
# health/20201116-120937__DSC0069.jpg ->  copy/Health
# health/20201116-121137__DSC0100.jpg ->  copy/Grade-1-2
# health/20201116-121206__DSC0103.jpg ->  copy/Grade-2
# health/20201116-121206__DSC0104.jpg ->  copy/Grade-2
# health/20201116-121331__DSC0123.jpg ->  copy/Grade-1
# health/20201116-121331__DSC0124.jpg ->  copy/Grade-1-2
# health/20201116-121351__DSC0128.jpg ->  copy/Grade-2
# health/20201116-121829__DSC0164.jpg ->  copy/Grade-1-2
# health/20201116-122358__DSC0207.jpg ->  copy/Grade-2
# health/20201116-122614__DSC0220.jpg ->  copy/Grade-2
# health/20201116-122718__DSC0233.jpg ->  copy/Grade-2
# health/20201116-122721__DSC0236.jpg ->  copy/Grade-2
# ...
